# %%
# !pip install gensim

# %%
import gensim
from gensim.models import Word2Vec,keyedvectors

# %%
# import gensim.downloader as api
# wv=api.load('word2vec-google-news-300')
# vec_king=wv['king']

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()

# %%
# corpus='''A few months back, when I initially began working at Office People, I developed an interest in Language Models, particularly Word2Vec. Being a native Python user, I naturally concentrated on Gensim’s Word2Vec implementation and looked for papers and tutorials online. I directly applied and duplicated code snippets from multiple sources, as any good data scientist would do. I delved further and deeper to attempt to understand what went wrong with my method, reading through Stackoverflow conversations, Gensim’s Google Groups, and the library’s documentation.'''
import pandas as pd
messages = pd.read_excel('./spamham.xlsx')
messages.shape
corpus=messages['data']
corpus[2]
# Out:
# "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"

# %%
# from nltk import sent_tokenize
# cor=[]
# for i in len(corpus):
#     review=[lem.lemmatize(le.lower()) for le in i.split()]
#     cor.append(' '.join(review))
# print(cor)
import re
cor = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', str(corpus[i]))
    review = review.lower()
    review = review.split()
    
    review = [lem.lemmatize(word) for word in review]
    review = ' '.join(review)
    cor.append(review)

# %%
from nltk import word_tokenize
finalcor=[]

for i in cor:
    finalcor.append(word_tokenize(i))
finalcor
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'n',
#   'great',
#   'world',
#   'la',
#   'e',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'u', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'a',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   't',
#   'c',
#   's',
#   'apply',
#   'over',
#   's'],
#  ['u', 'dun', 'say', 'so', 'early', 'hor', 'u', 'c', 'already', 'then', 'say'],
#  ['nah',
#   'i',
#   'don',
#   't',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   's',
#   'been',
#   'week',
#   's',
#   'now',
#   'and',
# ...

# %%
from gensim.utils import simple_preprocess
words=[]
for i in corpus:
        words.append(simple_preprocess(str(i)))
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'goes',
#   'to',
#   'usf',
#   'he',
#   'lives',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
# ...

# %%
model=Word2Vec(finalcor)

# %%
model.wv.index_to_key
# Out:
# ['i',
#  'to',
#  'you',
#  'a',
#  'the',
#  'u',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  's',
#  'that',
#  'have',
#  'on',
#  't',
#  'now',
#  'are',
#  'can',
#  'm',
#  'so',
#  'not',
#  'but',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'go',
#  'lt',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'got',
#  'like',
#  'time',
#  'good',
#  'am',
#  'then',
#  'wa',
#  'there',
#  'he',
#  'text',
#  'love',
#  'only',
#  'want',
#  'send',
#  'p',
#  'r',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'n',
#  'by',
#  'going',
#  'c',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'k',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'd',
#  'back',
#  'da',
#  'reply',
#  'our',
#  'dont',
#  'think',
# ...

# %%
model.corpus_count
# Out:
# 5572

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('customer')
# Out:
# [('offer', 0.9988216161727905),
#  ('service', 0.9986836910247803),
#  ('wk', 0.9986205101013184),
#  ('awarded', 0.9985117316246033),
#  ('com', 0.9984354376792908),
#  ('our', 0.9983661770820618),
#  ('win', 0.9983435273170471),
#  ('pobox', 0.9983249306678772),
#  ('please', 0.9982801675796509),
#  ('entry', 0.9982767105102539)]

# %%
model.wv['customer'].shape
# Out:
# (100,)

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm

# %%
from tqdm import tqdm
import time

# Define a loop
for i in tqdm(range(10)):
    # Simulate some computation
    time.sleep(0.5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.99it/s]

# %%
import numpy as np
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5572/5572 [00:01<00:00, 2894.93it/s]

# %%
len(X)
# Out:
# 5572

# %%
y=messages['label']

# %%
print(y.shape)
y[2]
# Out:
# (5572,)
# 'spam'

# %%
a=()
if a==():
    print('yes')
# Out:
# yes

# %%
print(len(X))
lists=[]
i=0
while(i<len(X)):
    
    a=X[i].shape
#     print(a,i)
    if a==():
        print(i)
        X.pop(i)
        lists.append(i)
        print(y[i])
    elif a[0] !=100:
        print(i)
    i+=1
# Out:
# 5572
# 451
# ham
# 782
# ham
# 1610
# ham
# 2100
# spam
# 2566
# ham
# 3265
# ham
# 3370
# ham
# 3735
# ham
# 3973
# ham
# 4284
# ham
# 4470
# ham
# 4611
# ham
# 4812
# ham
# 5160
# ham
# 5320
# ham
# 5399
# ham

# %%
lists
# Out:
# [451,
#  782,
#  1610,
#  2100,
#  2566,
#  3265,
#  3370,
#  3735,
#  3973,
#  4284,
#  4470,
#  4611,
#  4812,
#  5160,
#  5320,
#  5399]

# %%
print(len(X))
for i in lists:
    print(i)
    y=np.delete(y,i)
print(y.shape)
# Out:
# 5556
# 451
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 4
#       2 for i in lists:
#       3     print(i)
# ----> 4     y=np.delete(y,i)
#       5 print(y.shape)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5359, in delete(arr, obj, axis)
#    5356     new = arr[tuple(slobj)]
#    5358 if wrap:
# -> 5359     return wrap(new)
#    5360 else:
#    5361     return new
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2107, in NDFrame.__array_wrap__(self, result, context)
#    2105     return res
#    2106 d = self._construct_axes_dict(self._AXIS_ORDERS, copy=False)
# -> 2107 return self._constructor(res, **d).__finalize__(self, method="__array_wrap__")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:461, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
# ...

# %%
y=list(y)

# %%
for i in lists:
    y.pop(i)

# %%
x=np.array(X)

# %%
x.shape
# Out:
# (5556, 100)

# %%
y=np.array(y)

# %%
y.shape
# Out:
# (5556,)

# %%
y[1]
# Out:
# 'ham'

# %%
y=pd.get_dummies(y)
y=y.iloc[:,0].values

# %%
y[1]
# Out:
# 1

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
df=pd.DataFrame()
for i in range(0,len(X)):
    df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
# Out:
# C:\Users\gunas\AppData\Local\Temp\ipykernel_4164\4053554337.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)

# %%
df
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.196305  0.208481  0.027676 -0.024156  0.072026 -0.364225  0.258928
# 1    -0.150706  0.169472  0.032480 -0.030349  0.055288 -0.292488  0.216015
# 2    -0.178303  0.257242  0.043799 -0.009062  0.078979 -0.392192  0.287371
# 3    -0.261589  0.266940  0.050152 -0.040102  0.081690 -0.477287  0.346822
# 4    -0.225530  0.217008  0.037539 -0.006402  0.057548 -0.375236  0.284364
# ...        ...       ...       ...       ...       ...       ...       ...
# 5551 -0.214925  0.278305  0.027835 -0.026046  0.097086 -0.449537  0.331743
# 5552 -0.233224  0.256356  0.049784 -0.011492  0.066526 -0.436212  0.318518
# 5553 -0.264714  0.270197  0.032355 -0.031701  0.093749 -0.477116  0.341548
# 5554 -0.238632  0.255713  0.034208 -0.017796  0.082168 -0.442404  0.321169
# 5555 -0.209381  0.266536  0.046854  0.000237  0.085334 -0.429971  0.313564
#
# ...

# %%
df['Output']=y

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
from sklearn.ensemble import RandomForestClassifier
classfier=RandomForestClassifier()
classfier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=classfier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(pred,y_test))
# Out:
# 0.9658273381294964
